# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math
import random
import statistics as stat
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-146-5680a1f20ad2> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       3 import math
#       4 import random
#       5 import statistics as stat
#
# ImportError: No module named 'seaborn'

# %%
# (tail:head)
def flip_coin():
    counter = 1
    lists = []
    while counter <= 16:
        tails = 0
        heads = 0
        total = 2**counter
        for _ in range(total):
            random_flip = random.randint(1,2)
            if random_flip == 1:
                tails += 1
            else:
                heads += 1
        head_tail = [tails, heads]
        lists.append(head_tail)
        counter += 1

    return lists

# %%
print (flip_coin())
# Out:
# [[2, 0], [3, 1], [4, 4], [5, 11], [15, 17], [25, 39], [60, 68], [129, 127], [267, 245], [487, 537], [1008, 1040], [2000, 2096], [4073, 4119], [8197, 8187], [16408, 16360], [32856, 32680]]

# %%
#split into heads and tails
flip = flip_coin()
tails, heads = zip(*flip)
print ("Tails: ", tails)
print ("Heads: ", heads)
# Out:
# Tails:  (1, 3, 3, 4, 17, 29, 56, 119, 270, 501, 1012, 2031, 4167, 8170, 16369, 32828)
# Heads:  (1, 1, 5, 12, 15, 35, 72, 137, 242, 523, 1036, 2065, 4025, 8214, 16399, 32708)

# %%
difference_coin_flip = [abs(t-h) for t, h in zip(tails, heads)]
print (difference_coin_flip)
# Out:
# [0, 2, 2, 8, 2, 6, 16, 18, 28, 22, 24, 34, 142, 44, 30, 120]

# %%
x_range = range(1,17)
x1 = x_range
y1 = difference_coin_flip

plt.plot(y1)
plt.xticks(range(16), x1)
plt.xlabel('Intervals')
plt.ylabel('Difference')
plt.title('Difference - Coin Toss (Tails)')
plt.show()

# %%
x_range = range(1, 17)
x1 = x_range
y1 = ratio_coin_flip_head
y2 = ratio_coin_flip_tail

plt.plot(y1)
plt.plot(y2)

plt.xticks(range(17),x1)
plt.legend(['Heads', 'Tails'], loc='upper right')
plt.xlabel('Intervals')
plt.ylabel('Ratio (%)')
plt.title('Ratio of Head/Tails')
plt.grid(True)
plt.show()

# %%
interval = range(1,17)
difference = difference_coin_flip

plt.scatter(interval, difference)
plt.xlabel("Interval")
plt.ylabel("Difference")
plt.title('Scatter plot of differences between heads and tails')

plt.plot(interval, difference)
plt.grid(True)
plt.show()

# %%
def get_ratio_head(tails, heads):
    return [round((h/(h+t))*100, 1) for t, h in zip(tails, heads)]

def get_ratio_tail(tails, heads):
    return [round(t/(h+t)*100, 1) for t, h in zip(tails, heads)]

print ("Ratio to heads: ", get_ratio_head(tails, heads))
print ("Ratio to tails: ", get_ratio_tail())
# Out:
# Ratio to heads:  [50.0, 25.0, 62.5, 75.0, 46.9, 54.7, 56.2, 53.5, 47.3, 51.1, 50.6, 50.4, 49.1, 50.1, 50.0, 49.9]
# Ratio to tails:  [50.0, 75.0, 37.5, 25.0, 53.1, 45.3, 43.8, 46.5, 52.7, 48.9, 49.4, 49.6, 50.9, 49.9, 50.0, 50.1]

# %%
interval = range(1,17)

ratio_heads = ratio_coin_flip_head
ratio_tails = ratio_coin_flip_tail
# plt.scatter(interval, ratio_head)

# plt.xscale('log')
plt.semilogx(basex = 2)
plt.plot(interval, ratio_heads)
plt.plot(interval, ratio_tails)

plt.grid(True)
plt.xlabel("Interval")
plt.ylabel("Ratio (%)")
plt.title('Scatter plot of ratios between heads and tails')
plt.show()

# %%
def flip_coin_one_six_times(num):
    counter = 0
    tails = 0
    heads = 0
    total = int(2 ** num)
    for _ in range(total):
        random_num = random.randint(0,1)
        if random_num == 0:
            tails += 1
        else:
            heads += 1
        counter += 1
    list = [tails, heads]
    return list

# %%
list = []
for _ in range(20):
    flip_coin = flip_coin_one_six_times(16)
    list.append(flip_coin)
print (list)
# Out:
# [[32926, 32610], [32570, 32966], [32746, 32790], [32756, 32780], [32787, 32749], [32616, 32920], [32535, 33001], [32790, 32746], [32676, 32860], [32766, 32770], [32547, 32989], [32868, 32668], [32472, 33064], [32714, 32822], [32769, 32767], [32837, 32699], [32648, 32888], [32825, 32711], [32649, 32887], [32854, 32682]]

# %%
tails1, heads1 = zip(*list)
print ("Tails: ", tails)
print ("Heads: ", heads)
# Out:
# Tails:  (1, 3, 3, 4, 17, 29, 56, 119, 270, 501, 1012, 2031, 4167, 8170, 16369, 32828)
# Heads:  (1, 1, 5, 12, 15, 35, 72, 137, 242, 523, 1036, 2065, 4025, 8214, 16399, 32708)

# %%
print ("Ratio to heads: ", get_ratio_head(tails1, heads1))
print ("Ratio to tails: ", get_ratio_tail(tails1, heads1))
# Out:
# Ratio to heads:  [49.8, 50.3, 50.0, 50.0, 50.0, 50.2, 50.4, 50.0, 50.1, 50.0, 50.3, 49.8, 50.5, 50.1, 50.0, 49.9, 50.2, 49.9, 50.2, 49.9]
# Ratio to tails:  [50.2, 49.7, 50.0, 50.0, 50.0, 49.8, 49.6, 50.0, 49.9, 50.0, 49.7, 50.2, 49.5, 49.9, 50.0, 50.1, 49.8, 50.1, 49.8, 50.1]

# %%
x_range = range(0,21)

x1 = x_range
y1 = ratio_coin_flip_tail1

plt.scatter(ratio_coin_flip_head1, ratio_coin_flip_tail1)

plt.xticks(range(21), x1)
plt.xlabel('Trials of 2^16')
plt.ylabel('Ratio of heads to tails')
plt.title('Scatter plot of the mean head/tail ratio')
plt.show()

# %%
def flip_coin_one_hundred_times():
    counter = 1
    lists = []
    while counter <= 100000:
        tails = 0
        heads = 0
        for _ in range(100):
            random_flip = random.randint(1,2)
            if random_flip == 1:
                tails += 1
            else:
                heads += 1
        head_tail = [tails, heads]
        lists.append(head_tail)
        counter += 1

    return lists

# %%
print (flip_coin_one_hundred_times())
# Out:
, 49.0, 44.0, 54.0, 50.0, 50.0, 40.0, 53.0, 63.0, 51.0, 55.0, 60.0, 43.0, 45.0, 45.0, 53.0, 48.0, 47.0, 43.0, 46.0, 51.0, 55.0, 56.0, 58.0, 46.0, 51.0, 45.0, 42.0, 52.0, 55.0, 49.0, 44.0, 54.0, 52.0, 54.0, 45.0, 47.0, 47.0, 60.0, 50.0, 45.0, 48.0, 50.0, 45.0, 51.0, 44.0, 54.0, 56.0, 47.0, 55.0, 38.0, 54.0, 47.0, 53.0, 48.0, 57.0, 50.0, 52.0, 48.0, 56.0, 50.0, 57.0, 48.0, 39.0, 50.0, 50.0, 52.0, 52.0, 52.0, 51.0, 59.0, 46.0, 56.0, 49.0, 50.0, 46.0, 39.0, 50.0, 49.0, 52.0, 41.0, 48.0, 49.0, 54.0, 39.0, 55.0, 49.0, 45.0, 56.0, 57.0, 45.0, 51.0, 49.0, 53.0, 52.0, 47.0, 50.0, 44.0, 50.0, 57.0, 44.0, 50.0, 54.0, 49.0, 53.0, 55.0, 52.0, 48.0, 46.0, 59.0, 49.0, 51.0, 54.0, 54.0, 57.0, 54.0, 60.0, 50.0, 47.0, 53.0, 46.0, 42.0, 55.0, 51.0, 50.0, 51.0, 47.0, 46.0, 47.0, 59.0, 55.0, 53.0, 56.0, 51.0, 45.0, 51.0, 45.0, 51.0, 49.0, 45.0, 59.0, 53.0, 54.0, 60.0, 54.0, 56.0, 43.0, 39.0, 53.0, 44.0, 48.0, 51.0, 41.0, 44.0, 49.0, 50.0, 52.0, 53.0, 44.0, 41.0, 46.0, 54.0, 44.0, 51.0, 40.0, 52.0, 47.0, 44.0, 53.0, 56.0, 53.0, 50.0, 56.0, 45.0, 48.0, 51.0, 43.0, 43.0, 41.0, 53.0, 45.0, 50.0, 51.0, 51.0, 47.0, 49.0, 51.0, 57.0, 48.0, 46.0, 43.0, 51.0, 52.0, 56.0, 53.0, 51.0, 55.0, 47.0, 47.0, 53.0, 44.0, 55.0, 54.0, 49.0, 55.0, 49.0, 49.0, 56.0, 49.0, 48.0, 55.0, 60.0, 54.0, 43.0, 49.0, 48.0, 47.0, 53.0, 47.0, 46.0, 57.0, 63.0, 50.0, 51.0, 46.0, 52.0, 48.0, 46.0, 59.0, 49.0, 55.0, 50.0, 50.0, 55.0, 46.0, 62.0, 43.0, 51.0, 49.0, 50.0, 51.0, 50.0, 47.0, 46.0, 48.0, 45.0, 47.0, 50.0, 52.0, 58.0, 46.0, 47.0, 43.0, 49.0, 45.0, 53.0, 42.0 ...

# %%
thousand_ratio_head = get_ratio_head(tails2, heads2)

plt.hist(thousand_ratio_head)
mean = stat.mean(thousand_ratio_head)
stdev = stat.stdev(thousand_ratio_head)
ymin, ymax = plt.ylim()

plt.vlines(mean, ymin, ymax, color='red')
plt.vlines([mean - 2 * stdev, mean - stdev, mean + stdev, mean + 2 * stdev], ymin, ymax, color='red', linestyles='dashed')
plt.show()
# Out:
# -88
